# %%
import numpy as np

# %%
new_array = np.random.randint(1,100,20)

# %%
new_array
# Out:
# array([49, 49, 95, 31, 96, 74, 52,  1, 10, 47, 92, 79, 21, 72, 83, 62, 42,
#        47, 35, 99], dtype=int32)

# %%
new_array[new_array > 25]
# Out:
# array([49, 49, 95, 31, 96, 74, 52, 47, 92, 79, 72, 83, 62, 42, 47, 35, 99],
#       dtype=int32)

# %%
# transpose & reshape

# %%
matrix_array = np.array([[10,20],[20,30],[30,40]])

# %%
matrix_array
# Out:
# array([[10, 20],
#        [20, 30],
#        [30, 40]])

# %%
matrix_array.shape
# Out:
# (3, 2)

# %%
matrix_array.transpose()
# Out:
# array([[10, 20, 30],
#        [20, 30, 40]])

# %%
matrix_array.reshape(2,3)
# Out:
# array([[10, 20, 20],
#        [30, 30, 40]])
