# %%
import numpy as np

# %%
new_array = np.random.randint(1,100,20)

# %%
new_array
# Out:
# array([28, 35, 10, 31, 79, 81, 39, 93, 57, 24, 21, 57, 37, 65, 23, 60, 67,
#        34, 92, 18], dtype=int32)

# %%
new_array[new_array > 25]
# Out:
# array([28, 35, 31, 79, 81, 39, 93, 57, 57, 37, 65, 60, 67, 34, 92],
#       dtype=int32)

# %%
# transpose & reshape

# %%
matrix_array = np.array([[10,20],[20,30],[30,40]])

# %%
matrix_array
# Out:
# array([[10, 20],
#        [20, 30],
#        [30, 40]])

# %%
matrix_array.shape
# Out:
# (3, 2)

# %%
matrix_array.transpose()
# Out:
# array([[10, 20, 30],
#        [20, 30, 40]])

# %%
matrix_array.reshape(2,3)
# Out:
# array([[10, 20, 20],
#        [30, 30, 40]])
