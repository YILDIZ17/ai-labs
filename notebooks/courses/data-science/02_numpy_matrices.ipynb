# %%
# https://numpy.org/

# %%
import numpy as np

# %%
my_matrix = [[5,10],[15,20]]

# %%
my_matrix[0]
# Out:
# [5, 10]

# %%
my_matrix[0][1]
# Out:
# 10

# %%
# row * column

# %%
numpy_matrix = np.array([[5,10],[15,20]])

# %%
numpy_matrix
# Out:
# array([[ 5, 10],
#        [15, 20]])

# %%
numpy_matrix.sum()
# Out:
# np.int64(50)

# %%
int(numpy_matrix.sum())
# Out:
# 50

# %%
np.ones((4,2))
# Out:
# array([[1., 1.],
#        [1., 1.],
#        [1., 1.],
#        [1., 1.]])

# %%
np.random.random((3,2))
# Out:
# array([[0.53079925, 0.84614212],
#        [0.37937365, 0.35611998],
#        [0.62929345, 0.25066622]])

# %%
# matrix arithmetic

# %%
first_array = np.array([[10,20],[30,40]])

# %%
second_array = np.array([[5,15],[25,35]])

# %%
first_array + second_array
# Out:
# array([[15, 35],
#        [55, 75]])

# %%
second_array.shape
# Out:
# (2, 2)

# %%
# matrix multiplication (dot product)

# %%
first_matrix = np.array([[10,20,30]])

# %%
second_matrix = np.array([[2,3],[2,3],[2,3]])

# %%
first_matrix.shape
# Out:
# (1, 3)

# %%
second_matrix.shape
# Out:
# (3, 2)

# %%
result_matrix = first_matrix.dot(second_matrix)

# %%
result_matrix
# Out:
# array([[120, 180]])

# %%
result_matrix.shape
# Out:
# (1, 2)
