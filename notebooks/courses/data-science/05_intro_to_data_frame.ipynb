# %%
# https://pandas.pydata.org/

# %%
import numpy as np

# %%
import pandas as pd

# %%
data = np.random.randn(4,3)

# %%
data
# Out:
# array([[-0.80333428, -1.13447573,  0.89775209],
#        [ 0.48261466,  1.57507171, -0.28003965],
#        [-0.14579012, -1.20739435, -0.76968353],
#        [ 1.12393612,  0.70316969, -0.43474477]])

# %%
data_frame = pd.DataFrame(data)

# %%
data_frame
# Out:
#           0         1         2
# 0 -0.803334 -1.134476  0.897752
# 1  0.482615  1.575072 -0.280040
# 2 -0.145790 -1.207394 -0.769684
# 3  1.123936  0.703170 -0.434745

# %%
type(data_frame)
# Out:
# pandas.DataFrame

# %%
type(data_frame[0])
# Out:
# pandas.Series

# %%
new_df = pd.DataFrame(data, index = ["Safiye", "Haluk", "Saadet", "Atif"], columns = ["Salary", "Age", "Seniority"])

# %%
new_df
# Out:
#           Salary       Age  Seniority
# Safiye -0.803334 -1.134476   0.897752
# Haluk   0.482615  1.575072  -0.280040
# Saadet -0.145790 -1.207394  -0.769684
# Atif    1.123936  0.703170  -0.434745

# %%
new_df[["Age", "Salary"]]
# Out:
#              Age    Salary
# Safiye -1.134476 -0.803334
# Haluk   1.575072  0.482615
# Saadet -1.207394 -0.145790
# Atif    0.703170  1.123936

# %%
new_df.loc["Atif"]
# Out:
# Salary       1.123936
# Age          0.703170
# Seniority   -0.434745
# Name: Atif, dtype: float64

# %%
new_df.iloc[0] # row
# Out:
# Salary      -0.803334
# Age         -1.134476
# Seniority    0.897752
# Name: Safiye, dtype: float64

# %%
new_df.iloc[:,2] # : -> all row ,[i] -> choice of column
# Out:
# Safiye    0.897752
# Haluk    -0.280040
# Saadet   -0.769684
# Atif     -0.434745
# Name: Seniority, dtype: float64

# %%
new_df["Extra"] = 10

# %%
new_df
# Out:
#           Salary       Age  Seniority  Extra
# Safiye -0.803334 -1.134476   0.897752     10
# Haluk   0.482615  1.575072  -0.280040     10
# Saadet -0.145790 -1.207394  -0.769684     10
# Atif    1.123936  0.703170  -0.434745     10

# %%
new_df.drop("Extra", axis=1, inplace=True)

# %%
new_df
# Out:
#           Salary       Age  Seniority
# Safiye -0.803334 -1.134476   0.897752
# Haluk   0.482615  1.575072  -0.280040
# Saadet -0.145790 -1.207394  -0.769684
# Atif    1.123936  0.703170  -0.434745

# %%
new_df.loc["Saadet", "Salary"] = 100

# %%
new_df
# Out:
#             Salary       Age  Seniority
# Safiye   -0.803334 -1.134476   0.897752
# Haluk     0.482615  1.575072  -0.280040
# Saadet  100.000000 -1.207394  -0.769684
# Atif      1.123936  0.703170  -0.434745

# %%
new_df > 0
# Out:
#         Salary    Age  Seniority
# Safiye   False  False       True
# Haluk     True   True      False
# Saadet    True  False      False
# Atif      True   True      False

# %%
# index

# %%
reset_frame = new_df.reset_index()

# %%
reset_frame
# Out:
#     index      Salary       Age  Seniority
# 0  Safiye   -0.803334 -1.134476   0.897752
# 1   Haluk    0.482615  1.575072  -0.280040
# 2  Saadet  100.000000 -1.207394  -0.769684
# 3    Atif    1.123936  0.703170  -0.434745

# %%
new_df
# Out:
#             Salary       Age  Seniority
# Safiye   -0.803334 -1.134476   0.897752
# Haluk     0.482615  1.575072  -0.280040
# Saadet  100.000000 -1.207394  -0.769684
# Atif      1.123936  0.703170  -0.434745

# %%
new_indices = ["Saf", "Hal", "Sdt", "Atf"]

# %%
new_df["NewIndex"] = new_indices

# %%
new_df.set_index("NewIndex", inplace=True)

# %%
new_df
# Out:
#               Salary       Age  Seniority
# NewIndex
# Saf        -0.803334 -1.134476   0.897752
# Hal         0.482615  1.575072  -0.280040
# Sdt       100.000000 -1.207394  -0.769684
# Atf         1.123936  0.703170  -0.434745

# %%
# multi index

# %%
first_index = ["Kral Sakir", "Kral Sakir", "Kral Sakir", "Rafadan Tayfa", "Rafadan Tayfa", "Rafadan Tayfa"]

# %%
inner_index = ["Sakir", "Necati", "Canan", "Akin", "Hayri", "Mert"]

# %%
zipped_index = list(zip(first_index, inner_index))

# %%
zipped_index
# Out:
# [('Kral Sakir', 'Sakir'),
#  ('Kral Sakir', 'Necati'),
#  ('Kral Sakir', 'Canan'),
#  ('Rafadan Tayfa', 'Akin'),
#  ('Rafadan Tayfa', 'Hayri'),
#  ('Rafadan Tayfa', 'Mert')]

# %%
zipped_index = pd.MultiIndex.from_tuples(zipped_index)

# %%
zipped_index
# Out:
# MultiIndex([(   'Kral Sakir',  'Sakir'),
#             (   'Kral Sakir', 'Necati'),
#             (   'Kral Sakir',  'Canan'),
#             ('Rafadan Tayfa',   'Akin'),
#             ('Rafadan Tayfa',  'Hayri'),
#             ('Rafadan Tayfa',   'Mert')],
#            )

# %%
samples_values = np.ones((6,2))

# %%
big_df = pd.DataFrame(samples_values, index=zipped_index, columns = ["Age", "Salary"])

# %%
big_df
# Out:
#                       Age  Salary
# Kral Sakir    Sakir   1.0     1.0
#               Necati  1.0     1.0
#               Canan   1.0     1.0
# Rafadan Tayfa Akin    1.0     1.0
#               Hayri   1.0     1.0
#               Mert    1.0     1.0

# %%
big_df.loc["Kral Sakir"].loc["Sakir"]
# Out:
# Age       1.0
# Salary    1.0
# Name: Sakir, dtype: float64
