# %%
# https://pandas.pydata.org/

# %%
import numpy as np

# %%
import pandas as pd

# %%
data = np.random.randn(4,3)

# %%
data
# Out:
# array([[ 0.46210752, -1.7155897 , -0.86605382],
#        [ 0.26753813,  1.26361976, -0.28654579],
#        [-1.118614  , -0.68010247,  1.66558867],
#        [ 1.04431692, -0.07761708, -0.36117021]])

# %%
data_frame = pd.DataFrame(data)

# %%
data_frame
# Out:
#           0         1         2
# 0  0.462108 -1.715590 -0.866054
# 1  0.267538  1.263620 -0.286546
# 2 -1.118614 -0.680102  1.665589
# 3  1.044317 -0.077617 -0.361170

# %%
type(data_frame)
# Out:
# pandas.DataFrame

# %%
type(data_frame[0])
# Out:
# pandas.Series

# %%
new_df = pd.DataFrame(data, index = ["Safiye", "Haluk", "Saadet", "Atif"], columns = ["Salary", "Age", "Seniority"])

# %%
new_df
# Out:
#           Salary       Age  Seniority
# Safiye  0.462108 -1.715590  -0.866054
# Haluk   0.267538  1.263620  -0.286546
# Saadet -1.118614 -0.680102   1.665589
# Atif    1.044317 -0.077617  -0.361170

# %%
new_df[["Age", "Salary"]]
# Out:
#              Age    Salary
# Safiye -1.715590  0.462108
# Haluk   1.263620  0.267538
# Saadet -0.680102 -1.118614
# Atif   -0.077617  1.044317

# %%
new_df.loc["Atif"]
# Out:
# Salary       1.044317
# Age         -0.077617
# Seniority   -0.361170
# Name: Atif, dtype: float64

# %%
new_df.iloc[0] # row
# Out:
# Salary       0.462108
# Age         -1.715590
# Seniority   -0.866054
# Name: Safiye, dtype: float64

# %%
new_df.iloc[:,2] # : -> all row ,[i] -> choice of column
# Out:
# Safiye   -0.866054
# Haluk    -0.286546
# Saadet    1.665589
# Atif     -0.361170
# Name: Seniority, dtype: float64

# %%
new_df["Extra"] = 10

# %%
new_df
# Out:
#           Salary       Age  Seniority  Extra
# Safiye  0.462108 -1.715590  -0.866054     10
# Haluk   0.267538  1.263620  -0.286546     10
# Saadet -1.118614 -0.680102   1.665589     10
# Atif    1.044317 -0.077617  -0.361170     10

# %%
new_df.drop("Extra", axis=1, inplace=True)

# %%
new_df
# Out:
#           Salary       Age  Seniority
# Safiye  0.462108 -1.715590  -0.866054
# Haluk   0.267538  1.263620  -0.286546
# Saadet -1.118614 -0.680102   1.665589
# Atif    1.044317 -0.077617  -0.361170

# %%
new_df.loc["Saadet", "Salary"] = 100

# %%
new_df
# Out:
#             Salary       Age  Seniority
# Safiye    0.462108 -1.715590  -0.866054
# Haluk     0.267538  1.263620  -0.286546
# Saadet  100.000000 -0.680102   1.665589
# Atif      1.044317 -0.077617  -0.361170

# %%
new_df > 0
# Out:
#         Salary    Age  Seniority
# Safiye    True  False      False
# Haluk     True   True      False
# Saadet    True  False       True
# Atif      True  False      False

# %%
# index

# %%
reset_frame = new_df.reset_index()

# %%
reset_frame
# Out:
#     index      Salary       Age  Seniority
# 0  Safiye    0.462108 -1.715590  -0.866054
# 1   Haluk    0.267538  1.263620  -0.286546
# 2  Saadet  100.000000 -0.680102   1.665589
# 3    Atif    1.044317 -0.077617  -0.361170

# %%
new_df
# Out:
#             Salary       Age  Seniority
# Safiye    0.462108 -1.715590  -0.866054
# Haluk     0.267538  1.263620  -0.286546
# Saadet  100.000000 -0.680102   1.665589
# Atif      1.044317 -0.077617  -0.361170

# %%
new_indices = ["Saf", "Hal", "Sdt", "Atf"]

# %%
new_df["NewIndex"] = new_indices

# %%
new_df.set_index("NewIndex", inplace=True)

# %%
new_df
# Out:
#               Salary       Age  Seniority
# NewIndex
# Saf         0.462108 -1.715590  -0.866054
# Hal         0.267538  1.263620  -0.286546
# Sdt       100.000000 -0.680102   1.665589
# Atf         1.044317 -0.077617  -0.361170

# %%
# multi index

# %%
first_index = ["Kral Sakir", "Kral Sakir", "Kral Sakir", "Rafadan Tayfa", "Rafadan Tayfa", "Rafadan Tayfa"]

# %%
inner_index = ["Sakir", "Necati", "Canan", "Akin", "Hayri", "Mert"]

# %%
zipped_index = list(zip(first_index, inner_index))

# %%
zipped_index
# Out:
# [('Kral Sakir', 'Sakir'),
#  ('Kral Sakir', 'Necati'),
#  ('Kral Sakir', 'Canan'),
#  ('Rafadan Tayfa', 'Akin'),
#  ('Rafadan Tayfa', 'Hayri'),
#  ('Rafadan Tayfa', 'Mert')]

# %%
zipped_index = pd.MultiIndex.from_tuples(zipped_index)

# %%
zipped_index
# Out:
# MultiIndex([(   'Kral Sakir',  'Sakir'),
#             (   'Kral Sakir', 'Necati'),
#             (   'Kral Sakir',  'Canan'),
#             ('Rafadan Tayfa',   'Akin'),
#             ('Rafadan Tayfa',  'Hayri'),
#             ('Rafadan Tayfa',   'Mert')],
#            )

# %%
samples_values = np.ones((6,2))

# %%
big_df = pd.DataFrame(samples_values, index=zipped_index, columns = ["Age", "Salary"])

# %%
big_df
# Out:
#                       Age  Salary
# Kral Sakir    Sakir   1.0     1.0
#               Necati  1.0     1.0
#               Canan   1.0     1.0
# Rafadan Tayfa Akin    1.0     1.0
#               Hayri   1.0     1.0
#               Mert    1.0     1.0

# %%
big_df.loc["Kral Sakir"].loc["Sakir"]
# Out:
# Age       1.0
# Salary    1.0
# Name: Sakir, dtype: float64
