# %%
# https://pandas.pydata.org/

# %%
import numpy as np

# %%
import pandas as pd

# %%
# !pip install pandas

# %%
grades = {"Murat":50, "Hatice":60, "Salih":30}

# %%
pd.Series(grades)
# Out:
# Murat     50
# Hatice    60
# Salih     30
# dtype: int64

# %%
# with numpy

# %%
numpy_array = np.array([50,40,30,20])

# %%
pd.Series(numpy_array)
# Out:
# 0    50
# 1    40
# 2    30
# 3    20
# dtype: int64

# %%
# arithmetic

# %%
contest_result = pd.Series(data=[10,5,100], index=["Murat", "Hatice", "Salih"])

# %%
contest_result2 = pd.Series(data=[20,50,10], index=["Murat", "Hatice", "Salih"])

# %%
contest_result
# Out:
# Murat      10
# Hatice      5
# Salih     100
# dtype: int64

# %%
contest_result["Murat"]
# Out:
# np.int64(10)

# %%
final_resulat = contest_result + contest_result2

# %%
final_resulat
# Out:
# Murat      30
# Hatice     55
# Salih     110
# dtype: int64
